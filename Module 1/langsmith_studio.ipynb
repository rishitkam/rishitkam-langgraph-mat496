# %% [markdown]
# ## We have to first come inside the studio directory and execute this command
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## We have to follow this link to open the LangGraph studio which we ran locally
#
# ![image.png](attachment:image.png)
#
#
# ## It opens the LAngSmith studio in our browser

# %% [markdown]
# ## This is the LAngGraph studio where we can play around with Graphs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## we can even highlight what each node is doing
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## We can also add new threads
#
# ![image.png](attachment:image.png)
